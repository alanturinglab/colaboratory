# %% [markdown]
# <a href="https://colab.research.google.com/github/alanturinglab/colaboratory/blob/main/Distribucion_con_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Gráficas de distribución con pandas

# %%
# !pip install pandas
import pandas as pd

# %%
btc = pd.read_csv('https://alanturinglab.github.io/colaboratory/Datos/bitcoin.csv')
btc.plot.line(x='Fecha', y='Cierre')

# %%
btc.plot.scatter(x='Fecha', y='Cierre')

# %%
btc.plot.bar(x='Fecha', y='Cierre')

# %%
btc.Cierre.hist(bins=10)

# %%
btc_nueva = btc[["Apertura", "Minimo", "Maximo", "Cierre"]]
btc_nueva.plot.hist(bins=12, alpha=0.25)

# %%
btc_nueva.boxplot(column=['Apertura', 'Minimo', 'Cierre'])
